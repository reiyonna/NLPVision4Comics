# %% [markdown]
# ## Install YOLOv5

# %%
# ! git clone https://github.com/ultralytics/yolov5.git
# ! cd yolov5
! pip install -U -r /media/hpc-lavasa/Data/21_Reiyonna/yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 5.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.3/645.3 kB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.1
#     Uninstalling matplotlib-3.8.1:
#       Successfully uninstalled matplotlib-3.8.1
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.211
#     Uninstalling ultralytics-8.0.211:
#       Successfully uninstalled ultralytics-8.0.211
# ...

# %% [markdown]
# ## Install Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FUFofgREYhzkCMsWXuFQ")
project = rf.workspace("ibn-zohr-university").project("speech-bubbles-detection")
dataset = project.version(9).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to speech-bubbles-detection-9 in yolov5pytorch:: 100%|██████████| 9144/9144 [00:03<00:00, 2830.31it/s]

# %% [markdown]
# ## Make changes to data.yaml

# %% [markdown]
# ## Train the model

# %%
! python /media/hpc-lavasa/Data/21_Reiyonna/yolov5/train.py --img-size 500 --batch-size 16 --epochs 50 --data /media/hpc-lavasa/Data/21_Reiyonna/speech-bubbles-detection-9/data.yaml --cfg /media/hpc-lavasa/Data/21_Reiyonna/yolov5/models/yolov5s.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=/media/hpc-lavasa/Data/21_Reiyonna/yolov5/models/yolov5s.yaml, data=/media/hpc-lavasa/Data/21_Reiyonna/speech-bubbles-detection-9/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=500, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-243-g7c54e5d Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA RTX A6000, 45623MiB)
#
# ...

# %%
! python /media/hpc-lavasa/Data/21_Reiyonna/yolov5/detect.py --source /media/hpc-lavasa/Data/21_Reiyonna/speech-bubbles-detection-9/test/images/ --weights /media/hpc-lavasa/Data/21_Reiyonna/yolov5/runs/train/exp4/weights/best.pt --conf 0.5 --save-txt
# Out:
# detect: weights=['/media/hpc-lavasa/Data/21_Reiyonna/yolov5/runs/train/exp4/weights/best.pt'], source=/media/hpc-lavasa/Data/21_Reiyonna/speech-bubbles-detection-9/test/images/, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-243-g7c54e5d Python-3.11.5 torch-2.1.1+cu121 CUDA:0 (NVIDIA RTX A6000, 45623MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7026307 parameters, 0 gradients, 15.8 GFLOPs
# image 1/192 /media/hpc-lavasa/Data/21_Reiyonna/speech-bubbles-detection-9/test/images/-1005-_jpg.rf.dc6e39110e1d5a9acc448bffc6214063.jpg: 640x480 5 Elipses, 1 cloude, 38.6ms
# ...
